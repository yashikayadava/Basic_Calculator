# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'calci.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(308, 399)
        Form.setStyleSheet("background-color: rgb(0, 19, 29);")
        self.ac = QtWidgets.QPushButton(Form)
        self.ac.setGeometry(QtCore.QRect(20, 90, 61, 51))
        self.ac.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 10pt \"MS Shell Dlg 2\";")
        self.ac.setObjectName("ac")
        self.div = QtWidgets.QPushButton(Form)
        self.div.setGeometry(QtCore.QRect(90, 90, 61, 51))
        self.div.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.div.setObjectName("div")
        self.mul = QtWidgets.QPushButton(Form)
        self.mul.setGeometry(QtCore.QRect(160, 90, 61, 51))
        self.mul.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.mul.setObjectName("mul")
        self.clear = QtWidgets.QPushButton(Form)
        self.clear.setGeometry(QtCore.QRect(230, 90, 61, 51))
        self.clear.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.clear.setObjectName("clear")
        self.n7 = QtWidgets.QPushButton(Form)
        self.n7.setGeometry(QtCore.QRect(20, 150, 61, 51))
        self.n7.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n7.setObjectName("n7")
        self.n8 = QtWidgets.QPushButton(Form)
        self.n8.setGeometry(QtCore.QRect(90, 150, 61, 51))
        self.n8.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n8.setObjectName("n8")
        self.n9 = QtWidgets.QPushButton(Form)
        self.n9.setGeometry(QtCore.QRect(160, 150, 61, 51))
        self.n9.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n9.setObjectName("n9")
        self.sub = QtWidgets.QPushButton(Form)
        self.sub.setGeometry(QtCore.QRect(230, 150, 61, 51))
        self.sub.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 20pt \"MS Shell Dlg 2\";")
        self.sub.setObjectName("sub")
        self.n4 = QtWidgets.QPushButton(Form)
        self.n4.setGeometry(QtCore.QRect(20, 210, 61, 51))
        self.n4.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n4.setObjectName("n4")
        self.n5 = QtWidgets.QPushButton(Form)
        self.n5.setGeometry(QtCore.QRect(90, 210, 61, 51))
        self.n5.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n5.setObjectName("n5")
        self.n6 = QtWidgets.QPushButton(Form)
        self.n6.setGeometry(QtCore.QRect(160, 210, 61, 51))
        self.n6.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n6.setObjectName("n6")
        self.add = QtWidgets.QPushButton(Form)
        self.add.setGeometry(QtCore.QRect(230, 210, 61, 51))
        self.add.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 12pt \"MS Shell Dlg 2\";")
        self.add.setObjectName("add")
        self.n1 = QtWidgets.QPushButton(Form)
        self.n1.setGeometry(QtCore.QRect(20, 270, 61, 51))
        self.n1.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n1.setObjectName("n1")
        self.n2 = QtWidgets.QPushButton(Form)
        self.n2.setGeometry(QtCore.QRect(90, 270, 61, 51))
        self.n2.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n2.setObjectName("n2")
        self.n3 = QtWidgets.QPushButton(Form)
        self.n3.setGeometry(QtCore.QRect(160, 270, 61, 51))
        self.n3.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n3.setObjectName("n3")
        self.result = QtWidgets.QPushButton(Form)
        self.result.setGeometry(QtCore.QRect(230, 270, 61, 111))
        self.result.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(117, 156, 165, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 12pt \"MS Shell Dlg 2\";")
        self.result.setObjectName("result")
        self.mod = QtWidgets.QPushButton(Form)
        self.mod.setGeometry(QtCore.QRect(20, 330, 61, 51))
        self.mod.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.mod.setObjectName("mod")
        self.n0 = QtWidgets.QPushButton(Form)
        self.n0.setGeometry(QtCore.QRect(90, 330, 61, 51))
        self.n0.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 11pt \"MS Shell Dlg 2\";")
        self.n0.setObjectName("n0")
        self.dec = QtWidgets.QPushButton(Form)
        self.dec.setGeometry(QtCore.QRect(160, 330, 61, 51))
        self.dec.setStyleSheet("background-color: qradialgradient(spread:repeat, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(82, 136, 147, 255), stop:1 rgba(255, 255, 255, 255));\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.dec.setObjectName("dec")
        self.input = QtWidgets.QLabel(Form)
        self.input.setGeometry(QtCore.QRect(20, 10, 271, 71))
        self.input.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 20pt \"MS Shell Dlg 2\";")
        self.input.setText("")
        self.input.setAlignment(QtCore.Qt.AlignBottom|QtCore.Qt.AlignRight|QtCore.Qt.AlignTrailing)
        self.input.setObjectName("input")
        
        self.ac.clicked.connect(self.clearfunc)
        self.div.clicked.connect(self.divfunc)
        self.mul.clicked.connect(self.mulfunc)
        self.add.clicked.connect(self.addfunc)
        self.sub.clicked.connect(self.subfunc)
        self.result.clicked.connect(self.res)
        self.mod.clicked.connect(self.modfunc)
        self.n0.clicked.connect(self.zero)
        self.n1.clicked.connect(self.one)
        self.n2.clicked.connect(self.two)
        self.n3.clicked.connect(self.three)
        self.n4.clicked.connect(self.four)
        self.n5.clicked.connect(self.five)
        self.n6.clicked.connect(self.six)
        self.n7.clicked.connect(self.seven)
        self.n8.clicked.connect(self.eight)
        self.n9.clicked.connect(self.nine)
        self.clear.clicked.connect(self.dels)
        self.dec.clicked.connect(self.decfunc)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
    def clearfunc(self):
        self.input.clear()
    def divfunc(self):
        text=self.input.text()
        self.input.setText(text+'/')
    def zero(self):
        text=self.input.text()
        self.input.setText(text+'0')
    def one(self):
        text=self.input.text()
        self.input.setText(text+'1')
    def two(self):
        text=self.input.text()
        self.input.setText(text+'2')
    def three(self):
        text=self.input.text()
        self.input.setText(text+'3')
    def four(self):
        text=self.input.text()
        self.input.setText(text+'4')
    def five(self):
        text=self.input.text()
        self.input.setText(text+'5')
    def six(self):
        text=self.input.text()
        self.input.setText(text+'6')
    def seven(self):
        text=self.input.text()
        self.input.setText(text+'7')
    def eight(self):
        text=self.input.text()
        self.input.setText(text+'8')
    def nine(self):
        text=self.input.text()
        self.input.setText(text+'9')
    def mulfunc(self):
        text=self.input.text()
        self.input.setText(text+'X')
    def subfunc(self):
        text=self.input.text()
        self.input.setText(text+'-')
    def addfunc(self):
        text=self.input.text()
        self.input.setText(text+'+')
    def modfunc(self):
        text=self.input.text()
        self.input.setText(text+'%')
    def dels(self):
        text=self.input.text()
        self.input.setText(text[:-1])
    def decfunc(self):
        text=self.input.text()
        self.input.setText(text+'.')
    def res(self):
        results=eval(self.input.text())
        self.input.setText(str(results))

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Basic Calculator"))
        self.ac.setText(_translate("Form", "AC"))
        self.div.setText(_translate("Form", "/"))
        self.mul.setText(_translate("Form", "X"))
        self.clear.setText(_translate("Form", "C"))
        self.n7.setText(_translate("Form", "7"))
        self.n8.setText(_translate("Form", "8"))
        self.n9.setText(_translate("Form", "9"))
        self.sub.setText(_translate("Form", "-"))
        self.n4.setText(_translate("Form", "4"))
        self.n5.setText(_translate("Form", "5"))
        self.n6.setText(_translate("Form", "6"))
        self.add.setText(_translate("Form", "+"))
        self.n1.setText(_translate("Form", "1"))
        self.n2.setText(_translate("Form", "2"))
        self.n3.setText(_translate("Form", "3"))
        self.result.setText(_translate("Form", "="))
        self.mod.setText(_translate("Form", "%"))
        self.n0.setText(_translate("Form", "0"))
        self.dec.setText(_translate("Form", "."))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
